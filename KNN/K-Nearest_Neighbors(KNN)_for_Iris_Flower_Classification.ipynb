# %% [markdown]
# # K-Nearest Neighbors (KNN) for Iris Flower Classification

# %% [markdown]
# ### What it does:
# This project uses the K-Nearest Neighbors (KNN) algorithm to classify th

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
#Load Iris dataset

iris = load_iris()

X = iris.data #Features (input variables)
y = iris.target #Target variable (output to predict)

# %%
#Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#Create and train KNN model
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)

#Predictions
y_pred = model.predict(X_test)

#Evaluate the model
print('Accuracy:', accuracy_score(y_test, y_pred)) #Measure how well the model is performin
# Out:
# Accuracy: 1.0

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
k_range = range(1, 20)
scores = []

for k in k_range:
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    scores.append(accuracy_score(y_test, y_pred))

plt.plot(k_range, scores)
plt.xlabel('K Value')
plt.ylabel('Accuracy')
plt.title('Elbow Method for Optimal K')
plt.grid(True)
plt.show()
